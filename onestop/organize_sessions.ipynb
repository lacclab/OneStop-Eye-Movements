# %%
import re
from pathlib import Path

import pandas as pd


def find_matching_folders(directory: str) -> tuple[list[str], list[str]]:
    """
    Find all folders in the given directory that match a specific pattern.

    Parameters:
    directory (str): The directory to search.

    Returns:
    List[str]: A list of matching folders.
    """
    matching_folders = []
    pattern = r"[lL]\d+_\d+"

    for exp_folder in Path(directory).iterdir():
        if exp_folder.is_dir():
            result_folder = exp_folder / "results"
            if result_folder.is_dir():
                for result in result_folder.iterdir():
                    if re.match(pattern, result.name):
                        matching_folders.append(str(result))
                    elif ".DS_Store" not in result.name:
                        non_matching_folders.append(str(result))
    return matching_folders, non_matching_folders


def filter_folders(matching_folder: list[str], df_col: pd.Series) -> list[str]:
    """
    Filter a list of folders based on the values in a DataFrame column.

    Parameters:
    matching_folder (List[str]): The list of folders to filter.
    df_col (pd.Series): The DataFrame column to use for filtering.

    Returns:
    List[str]: The filtered list of folders.
    """
    filtered_folders = []
    for folder in matching_folder:
        for value in df_col:
            if str(value) in folder:
                filtered_folders.append(folder)
                break
    return filtered_folders

# %% [markdown]
# # Move excluded to excluded_results

# %%
df = pd.read_csv("trial_IA_ID_mismatch (2).csv")
df
# Out:
#     RECORDING_SESSION_LABEL  batch  article_id  paragraph_id  trial  \
# 0                    l9_491      1           5             4     21
# 1                    l9_491      1          10             4     26
# 2                   l57_484      2           3             2      4
# 3                   l57_501      2           3             2      4
# 4                   l59_485      2           3             2     21
# ..                      ...    ...         ...           ...    ...
# 155                 l40_458      3           9             2     58
# 156                 l36_394      3           9             2     62
# 157                 l36_400      3           9             2     62
# 158                 l56_438      3           9             2     63
# 159                 l56_464      3           9             2     63
#
#       missing_IA_IDs
# 0    (153, 154, 155)
# 1             (164,)
# 2             (146,)
# 3             (146,)
# 4             (146,)
# ..               ...
# 155  (160, 161, 159)
# 156  (0, 1, 2, 3, 4)
# 157  (160, 161, 159)
# 158  (160, 161, 159)
# 159  (0, 1, 2, 3, 4)
#
# [160 rows x 6 columns]

# %%
matching_folders_eye_data = find_matching_folders("/Users/shubi/Documents/eye_data")
filter_folders(matching_folders_eye_data, df)
# Out:
# []

# %%
matching_folders_onedrive = find_matching_folders(
    "/Users/shubi/Data/OneStop Full Experiment Folders Backup 1932024 after fixes"
)
[f for f in filter_folders(matching_folders_onedrive, df) if "report" not in f]
# Out:
# []

# %%
filtered_df = df[df["RECORDING_SESSION_LABEL"] == "l59_485"]
filtered_df
# Out:
#    RECORDING_SESSION_LABEL  batch  article_id  paragraph_id  trial  \
# 4                  l59_485      2           3             2     21
# 17                 l59_485      2           3             2     64
#
#    missing_IA_IDs
# 4          (146,)
# 17         (146,)

# %%
metadata_df = pd.read_csv("Metadata OneStopGaze L1 - metadata (4).csv")
metadata_df.Folder.value_counts()
# Out:
# ose_1n_l1_l60_tower_st                           57
# ose_2n_l1_l60_tower_st                           52
# ose_3n_l1_l60_tower_st_fixed                     51
# ose_1p_l1_l60_tower_st                           50
# ose_3p_l1_l60_tower_st_fixed                     49
# ose_2p_l1_l60_tower_st                           44
# ose_2p_l1_l60_tower_st_mit_l1_latest             12
# ose_3p_l1_l60_tower_st_mit_l1_latest_widthfix     6
# ose_2n_l1_l60_tower_st_mit_l1_latest_widthfix     5
# ose_3p_l1_l60_tower_st                            5
# ose_3n_l1_l60_tower_st                            4
# ose_1p_l1_l60_tower_iafix                         4
# ose_3n_l1_l60_tower_st_mit_l1_latest_widthfix     4
# ose_1p_l1_l60_tower_st_mit_l1_latest              3
# ose_1p_l1_l60_tower_st_mit_l1_latest_widthfix     3
# ose_2n_l1_l60_tower_st_mit_l1_latest              2
# ose_1n_l1_l60_tower_st_mit_l1_latest              2
# ose_2p_l1_l60_tower_st_mit_l1_latest_widthfix     2
# ose_2p_l1_l60_tower_st_mit_l2                     2
# ose_2n_l1_l60_tower_st_lacclab_corrected          1
# ose_3n_l1_l60_tower_st_mit_l1_latest              1
# ose_1n_l1_l60_tower_st_mit_l2_latest              1
# Name: Folder, dtype: int64

# %%
matching_folders_eye_data = find_matching_folders(
    "/Users/shubi/Data/OneStop Full Experiment Folders Backup 1932024 after fixes"
)

# %%
matches = [f for f in filter_folders(matching_folders_eye_data, metadata_df.Folder)]

# %%
df = pd.DataFrame(
    {
        "Folder": [path.split("/")[-3] for path in matches],
        "subject_id": [path.split("/")[-1] for path in matches],
    }
)
df
# Out:
#                                             Folder subject_id
# 0    ose_3p_l1_l60_tower_st_mit_l1_latest_widthfix   l42_2070
# 1    ose_3p_l1_l60_tower_st_mit_l1_latest_widthfix    l59_547
# 2    ose_3p_l1_l60_tower_st_mit_l1_latest_widthfix    l39_542
# 3    ose_3p_l1_l60_tower_st_mit_l1_latest_widthfix    l56_522
# 4    ose_3p_l1_l60_tower_st_mit_l1_latest_widthfix    l49_529
# ..                                             ...        ...
# 355                         ose_2n_l1_l60_tower_st    l16_218
# 356                         ose_2n_l1_l60_tower_st    l30_254
# 357                         ose_2n_l1_l60_tower_st    l15_210
# 358                         ose_2n_l1_l60_tower_st    l17_219
# 359                         ose_2n_l1_l60_tower_st    l19_230
#
# [360 rows x 2 columns]

# %%
df = pd.DataFrame(
    {
        "Folder": [path.split("/")[-3] for path in matches],
        "subject_id": [path.split("/")[-1] for path in matches],
    }
)
df = df[df["subject_id"].str.lower().isin(metadata_df["Filename"])]
print(len(df))
# Out:
# 360

# %%
df.groupby("Folder").count().sort_values("subject_id", ascending=False).index
# Out:
# Index(['ose_1n_l1_l60_tower_st', 'ose_1p_l1_l60_tower_st',
#        'ose_2n_l1_l60_tower_st', 'ose_2p_l1_l60_tower_st',
#        'ose_3p_l1_l60_tower_st_fixed', 'ose_3n_l1_l60_tower_st_fixed',
#        'ose_3n_l1_l60_tower_st_fixed_lacc',
#        'ose_3p_l1_l60_tower_st_fixed_lacc',
#        'ose_2p_l1_l60_tower_st_mit_l1_latest', 'ose_2n_l1_l60_tower_st_lacc',
#        'ose_3p_l1_l60_tower_st_mit_l1_latest_widthfix',
#        'ose_2n_l1_l60_tower_st_mit_l1_latest_widthfix',
#        'ose_3p_l1_l60_tower_st', 'ose_3n_l1_l60_tower_st',
#        'ose_3n_l1_l60_tower_st_mit_l1_latest_widthfix',
#        'ose_1p_l1_l60_tower_iafix',
#        'ose_1p_l1_l60_tower_st_mit_l1_latest_widthfix',
#        'ose_1p_l1_l60_tower_st_mit_l1_latest',
#        'ose_2n_l1_l60_tower_st_mit_l1_latest',
#        'ose_1n_l1_l60_tower_st_mit_l1_latest',
#        'ose_2p_l1_l60_tower_st_mit_l1_latest_widthfix',
#        'ose_2p_l1_l60_tower_st_mit_l2',
#        'ose_2n_l1_l60_tower_st_lacclab_corrected',
#        'ose_3n_l1_l60_tower_st_mit_l1_latest',
#        'ose_1n_l1_l60_tower_st_mit_l2_latest', 'ose_2p_l1_l60_tower_st_lacc'],
#       dtype='object', name='Folder')

# %%
metadata_df = pd.read_csv("Metadata OneStopGaze L1 - metadata (4).csv")

df = pd.DataFrame(
    {
        "Folder": [path.split("/")[-3] for path in matching_folders_eye_data],
        "subject_id": [path.split("/")[-1] for path in matching_folders_eye_data],
        "full_path": matching_folders_eye_data,
    }
)
df["is_in_metadata"] = (
    df["subject_id"].str.lower().isin(metadata_df["Filename"].str.lower())
)

mappings = {
    "ose_1n_l1_l60_tower_st": "old_mit",
    "ose_1p_l1_l60_tower_st": "old_mit",
    "ose_2n_l1_l60_tower_st": "old_mit",
    "ose_2p_l1_l60_tower_st": "old_mit",
    "ose_3p_l1_l60_tower_st": "old_mit",
    "ose_3n_l1_l60_tower_st": "old_mit",
    "ose_3p_l1_l60_tower_st_fixed": "old_mit",
    "ose_3n_l1_l60_tower_st_fixed": "old_mit",
    "ose_1p_l1_l60_tower_iafix": "old_mit",
    "ose_3n_l1_l60_tower_st_fixed_lacc": "fixed_lacc",
    "ose_3p_l1_l60_tower_st_fixed_lacc": "fixed_lacc",
    "ose_2n_l1_l60_tower_st_lacclab_corrected": "corrected_lacc",
    "ose_2n_l1_l60_tower_st_lacc": "old_lacc",
    "ose_2p_l1_l60_tower_st_lacc": "old_lacc",
    "ose_2n_l1_l60_tower_st_mit_l1_latest": "new_mit",
    "ose_2p_l1_l60_tower_st_mit_l1_latest": "new_mit",
    "ose_1n_l1_l60_tower_st_mit_l1_latest": "new_mit",
    "ose_1p_l1_l60_tower_st_mit_l1_latest": "new_mit",
    "ose_3n_l1_l60_tower_st_mit_l1_latest": "new_mit",
    "ose_1n_l1_l60_tower_st_mit_l2_latest": "new_mit",
    "ose_3p_l1_l60_tower_st_mit_l1_latest_widthfix": "new_mit",
    "ose_3n_l1_l60_tower_st_mit_l1_latest_widthfix": "new_mit",
    "ose_1p_l1_l60_tower_st_mit_l1_latest_widthfix": "new_mit",
    "ose_2n_l1_l60_tower_st_mit_l1_latest_widthfix": "new_mit",
    "ose_2p_l1_l60_tower_st_mit_l1_latest_widthfix": "new_mit",
    "ose_2p_l1_l60_tower_st_mit_l2": "new_mit",
}
df["mapping"] = df.Folder.map(mappings)
print(df.mapping.value_counts())
print("total:", len(df))
# Out:
# old_mit           260
# fixed_lacc         47
# new_mit            43
# old_lacc            9
# corrected_lacc      1
# Name: mapping, dtype: int64
# total: 360

# %%
non_unique_subject_ids = df[df.duplicated(subset="subject_id", keep=False)]
non_unique_subject_ids.sort_values("Folder")
# Out:
# Empty DataFrame
# Columns: [Folder, subject_id, full_path, is_in_metadata, mapping, batch-condition, batch, condition, list, principle_list]
# Index: []

# %%
non_unique_subject_ids.merge(
    metadata_df,
    left_on="subject_id",
    right_on="Filename",
    how="left",
    suffixes=("_folder", "_metadata"),
)[["subject_id", "Folder_folder", "Folder_metadata"]].sort_values("subject_id")
# Out:
# Empty DataFrame
# Columns: [subject_id, Folder_folder, Folder_metadata]
# Index: []

# %%
# List of tuples with subject_id and Folder_folder values for the rows to update
rows_to_update = [
    ("l14_349", "ose_3n_l1_l60_tower_st_fixed"),
    ("l18_358", "ose_3n_l1_l60_tower_st_fixed"),
    ("l34_398", "ose_3p_l1_l60_tower_st_fixed_lacc"),
    ("l44_305", "ose_2n_l1_l60_tower_st"),
]

# Update the 'is_in_metadata' column for the specified rows
for subject_id, folder_folder in rows_to_update:
    df.loc[
        (df["subject_id"] == subject_id) & (df["Folder"] == folder_folder),
        "is_in_metadata",
    ] = False

# %%
metadata_df[~metadata_df.Filename.str.lower().isin(df.subject_id.str.lower())]
# Out:
# Empty DataFrame
# Columns: [Batch, Condition, Folder, List, ID, Filename, L1, Date, Experimenter, First Name, Last Name, MIT/Technion, Craigslist, dominant eye, tracked eye, LEXTALE, Start Time, End Time, Drift Above, Drift Below, Comprehension, Comprehension.1, Black Screen, Experiment Notes, Survey notes, Dataviewer Inspection Notes (Shubi)]
# Index: []
#
# [0 rows x 26 columns]

# %%
df.groupby("Folder").count().sort_values("subject_id", ascending=False).rename(
    columns={"subject_id": "Participant count"}
)["Participant count"]
# Out:
# Folder
# ose_1n_l1_l60_tower_st                           57
# ose_1p_l1_l60_tower_st                           50
# ose_2n_l1_l60_tower_st                           44
# ose_2p_l1_l60_tower_st                           43
# ose_3p_l1_l60_tower_st_fixed                     27
# ose_3n_l1_l60_tower_st_fixed                     26
# ose_3n_l1_l60_tower_st_fixed_lacc                25
# ose_3p_l1_l60_tower_st_fixed_lacc                22
# ose_2p_l1_l60_tower_st_mit_l1_latest             12
# ose_2n_l1_l60_tower_st_lacc                       8
# ose_3p_l1_l60_tower_st_mit_l1_latest_widthfix     6
# ose_2n_l1_l60_tower_st_mit_l1_latest_widthfix     5
# ose_3p_l1_l60_tower_st                            5
# ose_3n_l1_l60_tower_st                            4
# ose_3n_l1_l60_tower_st_mit_l1_latest_widthfix     4
# ose_1p_l1_l60_tower_iafix                         4
# ose_1p_l1_l60_tower_st_mit_l1_latest_widthfix     3
# ose_1p_l1_l60_tower_st_mit_l1_latest              3
# ose_2n_l1_l60_tower_st_mit_l1_latest              2
# ose_1n_l1_l60_tower_st_mit_l1_latest              2
# ose_2p_l1_l60_tower_st_mit_l1_latest_widthfix     2
# ose_2p_l1_l60_tower_st_mit_l2                     2
# ose_2n_l1_l60_tower_st_lacclab_corrected          1
# ose_3n_l1_l60_tower_st_mit_l1_latest              1
# ose_1n_l1_l60_tower_st_mit_l2_latest              1
# ose_2p_l1_l60_tower_st_lacc                       1
# Name: Participant count, dtype: int64

# %%
df.mapping.value_counts()
# Out:
# old_mit           260
# fixed_lacc         47
# new_mit            20
# old_lacc            9
# corrected_lacc      1
# Name: mapping, dtype: int64

# %%
import shutil

for index, row in df.query("is_in_metadata == False").iterrows():
    folder_path = row["full_path"]
    new_folder_path = folder_path.replace("results", "excluded_results")
    print(folder_path, new_folder_path)
    shutil.move(folder_path, new_folder_path)

# %%
for folder in non_matching:
    # assert "results" should be in the path only once
    assert folder.count("results") == 1
    new_folder_path = folder.replace("results", "excluded_results")
    print(folder, new_folder_path)
    shutil.move(folder, new_folder_path)

# %%
def find_matching_folders2(directory: str) -> tuple[list[str], list[str]]:
    """
    Find all folders in the given directory that match a specific pattern.

    Parameters:
    directory (str): The directory to search.

    Returns:
    List[str]: A list of matching folders.
    """
    matching_folders = []
    pattern = r"[Ll]\d+_\d+"  # e.g. L1_1 or l1_1
    non_matching_folders = []
    for exp_folder in Path(directory).iterdir():
        if exp_folder.is_dir():
            result_folder = exp_folder / "runtime" / "dataviewer"
            if result_folder.is_dir():
                for result in result_folder.iterdir():
                    if re.match(pattern, result.name):
                        matching_folders.append(str(result))
                    elif ".DS_Store" not in result.name:
                        non_matching_folders.append(str(result))
    return matching_folders, non_matching_folders


matching_folders_eye_data, non_matching = find_matching_folders2(
    "/Users/shubi/Library/CloudStorage/OneDrive-Technion/In-lab Experiments/OneStopGaze L1 English/Full Experiment Folders"
)
matching_folders_eye_data += non_matching
df = pd.DataFrame(
    {
        "Folder": [path.split("/")[-3] for path in matching_folders_eye_data],
        "subject_id": [path.split("/")[-1] for path in matching_folders_eye_data],
        "full_path": matching_folders_eye_data,
    }
)
df["is_in_metadata"] = (
    df["subject_id"].str.lower().isin(metadata_df["Filename"].str.lower())
)
df
# Out:
#                                             Folder subject_id         mapping  \
# 0    ose_3p_l1_l60_tower_st_mit_l1_latest_widthfix   l42_2070         new_mit
# 6         ose_2n_l1_l60_tower_st_lacclab_corrected    l59_485  corrected_lacc
# 7                ose_3p_l1_l60_tower_st_fixed_lacc    l57_439      fixed_lacc
# 8                ose_3p_l1_l60_tower_st_fixed_lacc    l53_431      fixed_lacc
# 9                ose_3p_l1_l60_tower_st_fixed_lacc    l45_452      fixed_lacc
# ..                                             ...        ...             ...
# 355                         ose_2n_l1_l60_tower_st    l16_218         old_mit
# 356                         ose_2n_l1_l60_tower_st    l30_254         old_mit
# 357                         ose_2n_l1_l60_tower_st    l15_210         old_mit
# 358                         ose_2n_l1_l60_tower_st    l17_219         old_mit
# 359                         ose_2n_l1_l60_tower_st    l19_230         old_mit
#
#     batch-condition batch condition  list  principle_list
# 0                3p     3         p    42               6
# 6                2n     2         n    59               5
# 7                3p     3         p    57               3
# 8                3p     3         p    53               5
# 9                3p     3         p    45               3
# ..              ...   ...       ...   ...             ...
# 355              2n     2         n    16               4
# 356              2n     2         n    30               6
# 357              2n     2         n    15               3
# 358              2n     2         n    17               5
# 359              2n     2         n    19               1
#
# [339 rows x 8 columns]

# %%
for index, row in df.query("is_in_metadata == False").iterrows():
    folder_path = row["full_path"]
    new_folder_path = folder_path.replace("dataviewer", "excluded_dataviewer")
    print(folder_path, new_folder_path)
    shutil.move(folder_path, new_folder_path)
# Out:
# /Users/shubi/Library/CloudStorage/OneDrive-Technion/In-lab Experiments/OneStopGaze L1 English/Full Experiment Folders/ose_1n_l1_l60_tower_st/runtime/dataviewer/l39_124 /Users/shubi/Library/CloudStorage/OneDrive-Technion/In-lab Experiments/OneStopGaze L1 English/Full Experiment Folders/ose_1n_l1_l60_tower_st/runtime/excluded_dataviewer/l39_124
# /Users/shubi/Library/CloudStorage/OneDrive-Technion/In-lab Experiments/OneStopGaze L1 English/Full Experiment Folders/ose_1n_l1_l60_tower_st/runtime/dataviewer/l40_126 /Users/shubi/Library/CloudStorage/OneDrive-Technion/In-lab Experiments/OneStopGaze L1 English/Full Experiment Folders/ose_1n_l1_l60_tower_st/runtime/excluded_dataviewer/l40_126
# /Users/shubi/Library/CloudStorage/OneDrive-Technion/In-lab Experiments/OneStopGaze L1 English/Full Experiment Folders/ose_1n_l1_l60_tower_st/runtime/dataviewer/l41_128 /Users/shubi/Library/CloudStorage/OneDrive-Technion/In-lab Experiments/OneStopGaze L1 English/Full Experiment Folders/ose_1n_l1_l60_tower_st/runtime/excluded_dataviewer/l41_128
# /Users/shubi/Library/CloudStorage/OneDrive-Technion/In-lab Experiments/OneStopGaze L1 English/Full Experiment Folders/ose_1n_l1_l60_tower_st/runtime/dataviewer/l7_84 /Users/shubi/Library/CloudStorage/OneDrive-Technion/In-lab Experiments/OneStopGaze L1 English/Full Experiment Folders/ose_1n_l1_l60_tower_st/runtime/excluded_dataviewer/l7_84
# /Users/shubi/Library/CloudStorage/OneDrive-Technion/In-lab Experiments/OneStopGaze L1 English/Full Experiment Folders/ose_1n_l1_l60_tower_st/runtime/dataviewer/l28_109 /Users/shubi/Library/CloudStorage/OneDrive-Technion/In-lab Experiments/OneStopGaze L1 English/Full Experiment Folders/ose_1n_l1_l60_tower_st/runtime/excluded_dataviewer/l28_109
# /Users/shubi/Library/CloudStorage/OneDrive-Technion/In-lab Experiments/OneStopGaze L1 English/Full Experiment Folders/ose_1n_l1_l60_tower_st/runtime/dataviewer/l35_117 /Users/shubi/Library/CloudStorage/OneDrive-Technion/In-lab Experiments/OneStopGaze L1 English/Full Experiment Folders/ose_1n_l1_l60_tower_st/runtime/excluded_dataviewer/l35_117
# /Users/shubi/Library/CloudStorage/OneDrive-Technion/In-lab Experiments/OneStopGaze L1 English/Full Experiment Folders/ose_1n_l1_l60_tower_st/runtime/dataviewer/l44_132 /Users/shubi/Library/CloudStorage/OneDrive-Technion/In-lab Experiments/OneStopGaze L1 English/Full Experiment Folders/ose_1n_l1_l60_tower_st/runtime/excluded_dataviewer/l44_132
# /Users/shubi/Library/CloudStorage/OneDrive-Technion/In-lab Experiments/OneStopGaze L1 English/Full Experiment Folders/ose_1n_l1_l60_tower_st/runtime/dataviewer/l42_287 /Users/shubi/Library/CloudStorage/OneDrive-Technion/In-lab Experiments/OneStopGaze L1 English/Full Experiment Folders/ose_1n_l1_l60_tower_st/runtime/excluded_dataviewer/l42_287
# /Users/shubi/Library/CloudStorage/OneDrive-Technion/In-lab Experiments/OneStopGaze L1 English/Full Experiment Folders/ose_1n_l1_l60_tower_st/runtime/dataviewer/l51_146 /Users/shubi/Library/CloudStorage/OneDrive-Technion/In-lab Experiments/OneStopGaze L1 English/Full Experiment Folders/ose_1n_l1_l60_tower_st/runtime/excluded_dataviewer/l51_146
# /Users/shubi/Library/CloudStorage/OneDrive-Technion/In-lab Experiments/OneStopGaze L1 English/Full Experiment Folders/ose_1n_l1_l60_tower_st/runtime/dataviewer/l9_89 /Users/shubi/Library/CloudStorage/OneDrive-Technion/In-lab Experiments/OneStopGaze L1 English/Full Experiment Folders/ose_1n_l1_l60_tower_st/runtime/excluded_dataviewer/l9_89
# /Users/shubi/Library/CloudStorage/OneDrive-Technion/In-lab Experiments/OneStopGaze L1 English/Full Experiment Folders/ose_1n_l1_l60_tower_st/runtime/dataviewer/l32_279 /Users/shubi/Library/CloudStorage/OneDrive-Technion/In-lab Experiments/OneStopGaze L1 English/Full Experiment Folders/ose_1n_l1_l60_tower_st/runtime/excluded_dataviewer/l32_279
# /Users/shubi/Library/CloudStorage/OneDrive-Technion/In-lab Experiments/OneStopGaze L1 English/Full Experiment Folders/ose_1n_l1_l60_tower_st/runtime/dataviewer/l32_283 /Users/shubi/Library/CloudStorage/OneDrive-Technion/In-lab Experiments/OneStopGaze L1 English/Full Experiment Folders/ose_1n_l1_l60_tower_st/runtime/excluded_dataviewer/l32_283
# /Users/shubi/Library/CloudStorage/OneDrive-Technion/In-lab Experiments/OneStopGaze L1 English/Full Experiment Folders/ose_1n_l1_l60_tower_st/runtime/dataviewer/l8_88 /Users/shubi/Library/CloudStorage/OneDrive-Technion/In-lab Experiments/OneStopGaze L1 English/Full Experiment Folders/ose_1n_l1_l60_tower_st/runtime/excluded_dataviewer/l8_88
# /Users/shubi/Library/CloudStorage/OneDrive-Technion/In-lab Experiments/OneStopGaze L1 English/Full Experiment Folders/ose_1n_l1_l60_tower_st/runtime/dataviewer/l4_78 /Users/shubi/Library/CloudStorage/OneDrive-Technion/In-lab Experiments/OneStopGaze L1 English/Full Experiment Folders/ose_1n_l1_l60_tower_st/runtime/excluded_dataviewer/l4_78
# /Users/shubi/Library/CloudStorage/OneDrive-Technion/In-lab Experiments/OneStopGaze L1 English/Full Experiment Folders/ose_1n_l1_l60_tower_st/runtime/dataviewer/l7_266 /Users/shubi/Library/CloudStorage/OneDrive-Technion/In-lab Experiments/OneStopGaze L1 English/Full Experiment Folders/ose_1n_l1_l60_tower_st/runtime/excluded_dataviewer/l7_266
# /Users/shubi/Library/CloudStorage/OneDrive-Technion/In-lab Experiments/OneStopGaze L1 English/Full Experiment Folders/ose_1n_l1_l60_tower_st/runtime/dataviewer/l59_188 /Users/shubi/Library/CloudStorage/OneDrive-Technion/In-lab Experiments/OneStopGaze L1 English/Full Experiment Folders/ose_1n_l1_l60_tower_st/runtime/excluded_dataviewer/l59_188
# /Users/shubi/Library/CloudStorage/OneDrive-Technion/In-lab Experiments/OneStopGaze L1 English/Full Experiment Folders/ose_1n_l1_l60_tower_st/runtime/dataviewer/l59_186 /Users/shubi/Library/CloudStorage/OneDrive-Technion/In-lab Experiments/OneStopGaze L1 English/Full Experiment Folders/ose_1n_l1_l60_tower_st/runtime/excluded_dataviewer/l59_186
# /Users/shubi/Library/CloudStorage/OneDrive-Technion/In-lab Experiments/OneStopGaze L1 English/Full Experiment Folders/ose_1n_l1_l60_tower_st/runtime/dataviewer/l32_113 /Users/shubi/Library/CloudStorage/OneDrive-Technion/In-lab Experiments/OneStopGaze L1 English/Full Experiment Folders/ose_1n_l1_l60_tower_st/runtime/excluded_dataviewer/l32_113
# /Users/shubi/Library/CloudStorage/OneDrive-Technion/In-lab Experiments/OneStopGaze L1 English/Full Experiment Folders/ose_1n_l1_l60_tower_st/runtime/dataviewer/l58_175 /Users/shubi/Library/CloudStorage/OneDrive-Technion/In-lab Experiments/OneStopGaze L1 English/Full Experiment Folders/ose_1n_l1_l60_tower_st/runtime/excluded_dataviewer/l58_175
# /Users/shubi/Library/CloudStorage/OneDrive-Technion/In-lab Experiments/OneStopGaze L1 English/Full Experiment Folders/ose_1n_l1_l60_tower_st/runtime/dataviewer/l10_90 /Users/shubi/Library/CloudStorage/OneDrive-Technion/In-lab Experiments/OneStopGaze L1 English/Full Experiment Folders/ose_1n_l1_l60_tower_st/runtime/excluded_dataviewer/l10_90
# /Users/shubi/Library/CloudStorage/OneDrive-Technion/In-lab Experiments/OneStopGaze L1 English/Full Experiment Folders/ose_1n_l1_l60_tower_st/runtime/dataviewer/l32_114 /Users/shubi/Library/CloudStorage/OneDrive-Technion/In-lab Experiments/OneStopGaze L1 English/Full Experiment Folders/ose_1n_l1_l60_tower_st/runtime/excluded_dataviewer/l32_114
# /Users/shubi/Library/CloudStorage/OneDrive-Technion/In-lab Experiments/OneStopGaze L1 English/Full Experiment Folders/ose_1n_l1_l60_tower_st/runtime/dataviewer/l42_130 /Users/shubi/Library/CloudStorage/OneDrive-Technion/In-lab Experiments/OneStopGaze L1 English/Full Experiment Folders/ose_1n_l1_l60_tower_st/runtime/excluded_dataviewer/l42_130
# /Users/shubi/Library/CloudStorage/OneDrive-Technion/In-lab Experiments/OneStopGaze L1 English/Full Experiment Folders/ose_1n_l1_l60_tower_st/runtime/dataviewer/l2_173 /Users/shubi/Library/CloudStorage/OneDrive-Technion/In-lab Experiments/OneStopGaze L1 English/Full Experiment Folders/ose_1n_l1_l60_tower_st/runtime/excluded_dataviewer/l2_173
# /Users/shubi/Library/CloudStorage/OneDrive-Technion/In-lab Experiments/OneStopGaze L1 English/Full Experiment Folders/ose_1n_l1_l60_tower_st/runtime/dataviewer/l49_142 /Users/shubi/Library/CloudStorage/OneDrive-Technion/In-lab Experiments/OneStopGaze L1 English/Full Experiment Folders/ose_1n_l1_l60_tower_st/runtime/excluded_dataviewer/l49_142
# /Users/shubi/Library/CloudStorage/OneDrive-Technion/In-lab Experiments/OneStopGaze L1 English/Full Experiment Folders/ose_1n_l1_l60_tower_st/runtime/dataviewer/l59_292 /Users/shubi/Library/CloudStorage/OneDrive-Technion/In-lab Experiments/OneStopGaze L1 English/Full Experiment Folders/ose_1n_l1_l60_tower_st/runtime/excluded_dataviewer/l59_292
# /Users/shubi/Library/CloudStorage/OneDrive-Technion/In-lab Experiments/OneStopGaze L1 English/Full Experiment Folders/ose_3n_l1_l60_tower_st_fixed/runtime/dataviewer/l29_382 /Users/shubi/Library/CloudStorage/OneDrive-Technion/In-lab Experiments/OneStopGaze L1 English/Full Experiment Folders/ose_3n_l1_l60_tower_st_fixed/runtime/excluded_dataviewer/l29_382
# /Users/shubi/Library/CloudStorage/OneDrive-Technion/In-lab Experiments/OneStopGaze L1 English/Full Experiment Folders/ose_2p_l1_l60_tower_st/runtime/dataviewer/l18_221 /Users/shubi/Library/CloudStorage/OneDrive-Technion/In-lab Experiments/OneStopGaze L1 English/Full Experiment Folders/ose_2p_l1_l60_tower_st/runtime/excluded_dataviewer/l18_221
# /Users/shubi/Library/CloudStorage/OneDrive-Technion/In-lab Experiments/OneStopGaze L1 English/Full Experiment Folders/ose_2p_l1_l60_tower_st/runtime/dataviewer/l36_272 /Users/shubi/Library/CloudStorage/OneDrive-Technion/In-lab Experiments/OneStopGaze L1 English/Full Experiment Folders/ose_2p_l1_l60_tower_st/runtime/excluded_dataviewer/l36_272
# /Users/shubi/Library/CloudStorage/OneDrive-Technion/In-lab Experiments/OneStopGaze L1 English/Full Experiment Folders/ose_2p_l1_l60_tower_st/runtime/dataviewer/l3_162 /Users/shubi/Library/CloudStorage/OneDrive-Technion/In-lab Experiments/OneStopGaze L1 English/Full Experiment Folders/ose_2p_l1_l60_tower_st/runtime/excluded_dataviewer/l3_162
# /Users/shubi/Library/CloudStorage/OneDrive-Technion/In-lab Experiments/OneStopGaze L1 English/Full Experiment Folders/ose_2p_l1_l60_tower_st/runtime/dataviewer/l38_284 /Users/shubi/Library/CloudStorage/OneDrive-Technion/In-lab Experiments/OneStopGaze L1 English/Full Experiment Folders/ose_2p_l1_l60_tower_st/runtime/excluded_dataviewer/l38_284
# /Users/shubi/Library/CloudStorage/OneDrive-Technion/In-lab Experiments/OneStopGaze L1 English/Full Experiment Folders/ose_2p_l1_l60_tower_st/runtime/dataviewer/l34_259 /Users/shubi/Library/CloudStorage/OneDrive-Technion/In-lab Experiments/OneStopGaze L1 English/Full Experiment Folders/ose_2p_l1_l60_tower_st/runtime/excluded_dataviewer/l34_259
# /Users/shubi/Library/CloudStorage/OneDrive-Technion/In-lab Experiments/OneStopGaze L1 English/Full Experiment Folders/ose_2p_l1_l60_tower_st/runtime/dataviewer/l10_196 /Users/shubi/Library/CloudStorage/OneDrive-Technion/In-lab Experiments/OneStopGaze L1 English/Full Experiment Folders/ose_2p_l1_l60_tower_st/runtime/excluded_dataviewer/l10_196
# /Users/shubi/Library/CloudStorage/OneDrive-Technion/In-lab Experiments/OneStopGaze L1 English/Full Experiment Folders/ose_2p_l1_l60_tower_st/runtime/dataviewer/l49_318 /Users/shubi/Library/CloudStorage/OneDrive-Technion/In-lab Experiments/OneStopGaze L1 English/Full Experiment Folders/ose_2p_l1_l60_tower_st/runtime/excluded_dataviewer/l49_318
# /Users/shubi/Library/CloudStorage/OneDrive-Technion/In-lab Experiments/OneStopGaze L1 English/Full Experiment Folders/ose_2p_l1_l60_tower_st/runtime/dataviewer/l31_250 /Users/shubi/Library/CloudStorage/OneDrive-Technion/In-lab Experiments/OneStopGaze L1 English/Full Experiment Folders/ose_2p_l1_l60_tower_st/runtime/excluded_dataviewer/l31_250
# /Users/shubi/Library/CloudStorage/OneDrive-Technion/In-lab Experiments/OneStopGaze L1 English/Full Experiment Folders/ose_2p_l1_l60_tower_st/runtime/dataviewer/l9_193 /Users/shubi/Library/CloudStorage/OneDrive-Technion/In-lab Experiments/OneStopGaze L1 English/Full Experiment Folders/ose_2p_l1_l60_tower_st/runtime/excluded_dataviewer/l9_193
# /Users/shubi/Library/CloudStorage/OneDrive-Technion/In-lab Experiments/OneStopGaze L1 English/Full Experiment Folders/ose_2p_l1_l60_tower_st/runtime/dataviewer/l9_194 /Users/shubi/Library/CloudStorage/OneDrive-Technion/In-lab Experiments/OneStopGaze L1 English/Full Experiment Folders/ose_2p_l1_l60_tower_st/runtime/excluded_dataviewer/l9_194
# /Users/shubi/Library/CloudStorage/OneDrive-Technion/In-lab Experiments/OneStopGaze L1 English/Full Experiment Folders/ose_2p_l1_l60_tower_st/runtime/dataviewer/l11_197 /Users/shubi/Library/CloudStorage/OneDrive-Technion/In-lab Experiments/OneStopGaze L1 English/Full Experiment Folders/ose_2p_l1_l60_tower_st/runtime/excluded_dataviewer/l11_197
# /Users/shubi/Library/CloudStorage/OneDrive-Technion/In-lab Experiments/OneStopGaze L1 English/Full Experiment Folders/ose_2p_l1_l60_tower_st/runtime/dataviewer/l19_223 /Users/shubi/Library/CloudStorage/OneDrive-Technion/In-lab Experiments/OneStopGaze L1 English/Full Experiment Folders/ose_2p_l1_l60_tower_st/runtime/excluded_dataviewer/l19_223
# /Users/shubi/Library/CloudStorage/OneDrive-Technion/In-lab Experiments/OneStopGaze L1 English/Full Experiment Folders/ose_2p_l1_l60_tower_st/runtime/dataviewer/l27_240 /Users/shubi/Library/CloudStorage/OneDrive-Technion/In-lab Experiments/OneStopGaze L1 English/Full Experiment Folders/ose_2p_l1_l60_tower_st/runtime/excluded_dataviewer/l27_240
# /Users/shubi/Library/CloudStorage/OneDrive-Technion/In-lab Experiments/OneStopGaze L1 English/Full Experiment Folders/ose_2p_l1_l60_tower_st/runtime/dataviewer/l20_224 /Users/shubi/Library/CloudStorage/OneDrive-Technion/In-lab Experiments/OneStopGaze L1 English/Full Experiment Folders/ose_2p_l1_l60_tower_st/runtime/excluded_dataviewer/l20_224
# /Users/shubi/Library/CloudStorage/OneDrive-Technion/In-lab Experiments/OneStopGaze L1 English/Full Experiment Folders/ose_2p_l1_l60_tower_st/runtime/dataviewer/l16_216 /Users/shubi/Library/CloudStorage/OneDrive-Technion/In-lab Experiments/OneStopGaze L1 English/Full Experiment Folders/ose_2p_l1_l60_tower_st/runtime/excluded_dataviewer/l16_216
# /Users/shubi/Library/CloudStorage/OneDrive-Technion/In-lab Experiments/OneStopGaze L1 English/Full Experiment Folders/ose_2p_l1_l60_tower_st/runtime/dataviewer/l14_211 /Users/shubi/Library/CloudStorage/OneDrive-Technion/In-lab Experiments/OneStopGaze L1 English/Full Experiment Folders/ose_2p_l1_l60_tower_st/runtime/excluded_dataviewer/l14_211
# /Users/shubi/Library/CloudStorage/OneDrive-Technion/In-lab Experiments/OneStopGaze L1 English/Full Experiment Folders/ose_2p_l1_l60_tower_st/runtime/dataviewer/l17_217 /Users/shubi/Library/CloudStorage/OneDrive-Technion/In-lab Experiments/OneStopGaze L1 English/Full Experiment Folders/ose_2p_l1_l60_tower_st/runtime/excluded_dataviewer/l17_217
# /Users/shubi/Library/CloudStorage/OneDrive-Technion/In-lab Experiments/OneStopGaze L1 English/Full Experiment Folders/ose_2p_l1_l60_tower_st/runtime/dataviewer/l44_304 /Users/shubi/Library/CloudStorage/OneDrive-Technion/In-lab Experiments/OneStopGaze L1 English/Full Experiment Folders/ose_2p_l1_l60_tower_st/runtime/excluded_dataviewer/l44_304
# /Users/shubi/Library/CloudStorage/OneDrive-Technion/In-lab Experiments/OneStopGaze L1 English/Full Experiment Folders/ose_2p_l1_l60_tower_st/runtime/dataviewer/l48_314 /Users/shubi/Library/CloudStorage/OneDrive-Technion/In-lab Experiments/OneStopGaze L1 English/Full Experiment Folders/ose_2p_l1_l60_tower_st/runtime/excluded_dataviewer/l48_314
# /Users/shubi/Library/CloudStorage/OneDrive-Technion/In-lab Experiments/OneStopGaze L1 English/Full Experiment Folders/ose_3p_l1_l60_tower_st_fixed/runtime/dataviewer/l29_381 /Users/shubi/Library/CloudStorage/OneDrive-Technion/In-lab Experiments/OneStopGaze L1 English/Full Experiment Folders/ose_3p_l1_l60_tower_st_fixed/runtime/excluded_dataviewer/l29_381
# /Users/shubi/Library/CloudStorage/OneDrive-Technion/In-lab Experiments/OneStopGaze L1 English/Full Experiment Folders/ose_3p_l1_l60_tower_st_fixed/runtime/dataviewer/l33_390 /Users/shubi/Library/CloudStorage/OneDrive-Technion/In-lab Experiments/OneStopGaze L1 English/Full Experiment Folders/ose_3p_l1_l60_tower_st_fixed/runtime/excluded_dataviewer/l33_390
# /Users/shubi/Library/CloudStorage/OneDrive-Technion/In-lab Experiments/OneStopGaze L1 English/Full Experiment Folders/ose_3p_l1_l60_tower_st_fixed/runtime/dataviewer/l30_384 /Users/shubi/Library/CloudStorage/OneDrive-Technion/In-lab Experiments/OneStopGaze L1 English/Full Experiment Folders/ose_3p_l1_l60_tower_st_fixed/runtime/excluded_dataviewer/l30_384
# /Users/shubi/Library/CloudStorage/OneDrive-Technion/In-lab Experiments/OneStopGaze L1 English/Full Experiment Folders/ose_3p_l1_l60_tower_st_fixed/runtime/dataviewer/l9_337 /Users/shubi/Library/CloudStorage/OneDrive-Technion/In-lab Experiments/OneStopGaze L1 English/Full Experiment Folders/ose_3p_l1_l60_tower_st_fixed/runtime/excluded_dataviewer/l9_337
# /Users/shubi/Library/CloudStorage/OneDrive-Technion/In-lab Experiments/OneStopGaze L1 English/Full Experiment Folders/ose_3p_l1_l60_tower_st_fixed/runtime/dataviewer/l23_369 /Users/shubi/Library/CloudStorage/OneDrive-Technion/In-lab Experiments/OneStopGaze L1 English/Full Experiment Folders/ose_3p_l1_l60_tower_st_fixed/runtime/excluded_dataviewer/l23_369
# /Users/shubi/Library/CloudStorage/OneDrive-Technion/In-lab Experiments/OneStopGaze L1 English/Full Experiment Folders/ose_3p_l1_l60_tower_st_fixed/runtime/dataviewer/l13_346 /Users/shubi/Library/CloudStorage/OneDrive-Technion/In-lab Experiments/OneStopGaze L1 English/Full Experiment Folders/ose_3p_l1_l60_tower_st_fixed/runtime/excluded_dataviewer/l13_346
# /Users/shubi/Library/CloudStorage/OneDrive-Technion/In-lab Experiments/OneStopGaze L1 English/Full Experiment Folders/ose_3p_l1_l60_tower_st_fixed/runtime/dataviewer/l18_357 /Users/shubi/Library/CloudStorage/OneDrive-Technion/In-lab Experiments/OneStopGaze L1 English/Full Experiment Folders/ose_3p_l1_l60_tower_st_fixed/runtime/excluded_dataviewer/l18_357
# /Users/shubi/Library/CloudStorage/OneDrive-Technion/In-lab Experiments/OneStopGaze L1 English/Full Experiment Folders/ose_3p_l1_l60_tower_st_fixed/runtime/dataviewer/l8_334 /Users/shubi/Library/CloudStorage/OneDrive-Technion/In-lab Experiments/OneStopGaze L1 English/Full Experiment Folders/ose_3p_l1_l60_tower_st_fixed/runtime/excluded_dataviewer/l8_334
# /Users/shubi/Library/CloudStorage/OneDrive-Technion/In-lab Experiments/OneStopGaze L1 English/Full Experiment Folders/ose_1p_l1_l60_tower_st/runtime/dataviewer/l18_274 /Users/shubi/Library/CloudStorage/OneDrive-Technion/In-lab Experiments/OneStopGaze L1 English/Full Experiment Folders/ose_1p_l1_l60_tower_st/runtime/excluded_dataviewer/l18_274
# /Users/shubi/Library/CloudStorage/OneDrive-Technion/In-lab Experiments/OneStopGaze L1 English/Full Experiment Folders/ose_1p_l1_l60_tower_st/runtime/dataviewer/l15_44 /Users/shubi/Library/CloudStorage/OneDrive-Technion/In-lab Experiments/OneStopGaze L1 English/Full Experiment Folders/ose_1p_l1_l60_tower_st/runtime/excluded_dataviewer/l15_44
# /Users/shubi/Library/CloudStorage/OneDrive-Technion/In-lab Experiments/OneStopGaze L1 English/Full Experiment Folders/ose_1p_l1_l60_tower_st/runtime/dataviewer/l35_81 /Users/shubi/Library/CloudStorage/OneDrive-Technion/In-lab Experiments/OneStopGaze L1 English/Full Experiment Folders/ose_1p_l1_l60_tower_st/runtime/excluded_dataviewer/l35_81
# /Users/shubi/Library/CloudStorage/OneDrive-Technion/In-lab Experiments/OneStopGaze L1 English/Full Experiment Folders/ose_1p_l1_l60_tower_st/runtime/dataviewer/l18_275 /Users/shubi/Library/CloudStorage/OneDrive-Technion/In-lab Experiments/OneStopGaze L1 English/Full Experiment Folders/ose_1p_l1_l60_tower_st/runtime/excluded_dataviewer/l18_275
# /Users/shubi/Library/CloudStorage/OneDrive-Technion/In-lab Experiments/OneStopGaze L1 English/Full Experiment Folders/ose_1p_l1_l60_tower_st/runtime/dataviewer/l56_181 /Users/shubi/Library/CloudStorage/OneDrive-Technion/In-lab Experiments/OneStopGaze L1 English/Full Experiment Folders/ose_1p_l1_l60_tower_st/runtime/excluded_dataviewer/l56_181
# /Users/shubi/Library/CloudStorage/OneDrive-Technion/In-lab Experiments/OneStopGaze L1 English/Full Experiment Folders/ose_1p_l1_l60_tower_st/runtime/dataviewer/l18_49 /Users/shubi/Library/CloudStorage/OneDrive-Technion/In-lab Experiments/OneStopGaze L1 English/Full Experiment Folders/ose_1p_l1_l60_tower_st/runtime/excluded_dataviewer/l18_49
# /Users/shubi/Library/CloudStorage/OneDrive-Technion/In-lab Experiments/OneStopGaze L1 English/Full Experiment Folders/ose_1p_l1_l60_tower_st/runtime/dataviewer/l43_134 /Users/shubi/Library/CloudStorage/OneDrive-Technion/In-lab Experiments/OneStopGaze L1 English/Full Experiment Folders/ose_1p_l1_l60_tower_st/runtime/excluded_dataviewer/l43_134
# /Users/shubi/Library/CloudStorage/OneDrive-Technion/In-lab Experiments/OneStopGaze L1 English/Full Experiment Folders/ose_1p_l1_l60_tower_st/runtime/dataviewer/l33_77 /Users/shubi/Library/CloudStorage/OneDrive-Technion/In-lab Experiments/OneStopGaze L1 English/Full Experiment Folders/ose_1p_l1_l60_tower_st/runtime/excluded_dataviewer/l33_77
# /Users/shubi/Library/CloudStorage/OneDrive-Technion/In-lab Experiments/OneStopGaze L1 English/Full Experiment Folders/ose_1p_l1_l60_tower_st/runtime/dataviewer/l17_47 /Users/shubi/Library/CloudStorage/OneDrive-Technion/In-lab Experiments/OneStopGaze L1 English/Full Experiment Folders/ose_1p_l1_l60_tower_st/runtime/excluded_dataviewer/l17_47
# /Users/shubi/Library/CloudStorage/OneDrive-Technion/In-lab Experiments/OneStopGaze L1 English/Full Experiment Folders/ose_1p_l1_l60_tower_st/runtime/dataviewer/l41_133 /Users/shubi/Library/CloudStorage/OneDrive-Technion/In-lab Experiments/OneStopGaze L1 English/Full Experiment Folders/ose_1p_l1_l60_tower_st/runtime/excluded_dataviewer/l41_133
# /Users/shubi/Library/CloudStorage/OneDrive-Technion/In-lab Experiments/OneStopGaze L1 English/Full Experiment Folders/ose_1p_l1_l60_tower_st/runtime/dataviewer/l60_192 /Users/shubi/Library/CloudStorage/OneDrive-Technion/In-lab Experiments/OneStopGaze L1 English/Full Experiment Folders/ose_1p_l1_l60_tower_st/runtime/excluded_dataviewer/l60_192
# /Users/shubi/Library/CloudStorage/OneDrive-Technion/In-lab Experiments/OneStopGaze L1 English/Full Experiment Folders/ose_1p_l1_l60_tower_st/runtime/dataviewer/l18_271 /Users/shubi/Library/CloudStorage/OneDrive-Technion/In-lab Experiments/OneStopGaze L1 English/Full Experiment Folders/ose_1p_l1_l60_tower_st/runtime/excluded_dataviewer/l18_271
# /Users/shubi/Library/CloudStorage/OneDrive-Technion/In-lab Experiments/OneStopGaze L1 English/Full Experiment Folders/ose_1p_l1_l60_tower_st/runtime/dataviewer/l57_182 /Users/shubi/Library/CloudStorage/OneDrive-Technion/In-lab Experiments/OneStopGaze L1 English/Full Experiment Folders/ose_1p_l1_l60_tower_st/runtime/excluded_dataviewer/l57_182
# /Users/shubi/Library/CloudStorage/OneDrive-Technion/In-lab Experiments/OneStopGaze L1 English/Full Experiment Folders/ose_1p_l1_l60_tower_st/runtime/dataviewer/l42_178 /Users/shubi/Library/CloudStorage/OneDrive-Technion/In-lab Experiments/OneStopGaze L1 English/Full Experiment Folders/ose_1p_l1_l60_tower_st/runtime/excluded_dataviewer/l42_178
# /Users/shubi/Library/CloudStorage/OneDrive-Technion/In-lab Experiments/OneStopGaze L1 English/Full Experiment Folders/ose_1p_l1_l60_tower_st/runtime/dataviewer/l8_75 /Users/shubi/Library/CloudStorage/OneDrive-Technion/In-lab Experiments/OneStopGaze L1 English/Full Experiment Folders/ose_1p_l1_l60_tower_st/runtime/excluded_dataviewer/l8_75
# /Users/shubi/Library/CloudStorage/OneDrive-Technion/In-lab Experiments/OneStopGaze L1 English/Full Experiment Folders/ose_1p_l1_l60_tower_st/runtime/dataviewer/l56_184 /Users/shubi/Library/CloudStorage/OneDrive-Technion/In-lab Experiments/OneStopGaze L1 English/Full Experiment Folders/ose_1p_l1_l60_tower_st/runtime/excluded_dataviewer/l56_184
# /Users/shubi/Library/CloudStorage/OneDrive-Technion/In-lab Experiments/OneStopGaze L1 English/Full Experiment Folders/ose_1p_l1_l60_tower_st/runtime/dataviewer/l34_79 /Users/shubi/Library/CloudStorage/OneDrive-Technion/In-lab Experiments/OneStopGaze L1 English/Full Experiment Folders/ose_1p_l1_l60_tower_st/runtime/excluded_dataviewer/l34_79
# /Users/shubi/Library/CloudStorage/OneDrive-Technion/In-lab Experiments/OneStopGaze L1 English/Full Experiment Folders/ose_1p_l1_l60_tower_st/runtime/dataviewer/l43_136 /Users/shubi/Library/CloudStorage/OneDrive-Technion/In-lab Experiments/OneStopGaze L1 English/Full Experiment Folders/ose_1p_l1_l60_tower_st/runtime/excluded_dataviewer/l43_136
# /Users/shubi/Library/CloudStorage/OneDrive-Technion/In-lab Experiments/OneStopGaze L1 English/Full Experiment Folders/ose_1p_l1_l60_tower_st/runtime/dataviewer/l36_86 /Users/shubi/Library/CloudStorage/OneDrive-Technion/In-lab Experiments/OneStopGaze L1 English/Full Experiment Folders/ose_1p_l1_l60_tower_st/runtime/excluded_dataviewer/l36_86
# /Users/shubi/Library/CloudStorage/OneDrive-Technion/In-lab Experiments/OneStopGaze L1 English/Full Experiment Folders/ose_1p_l1_l60_tower_st/runtime/dataviewer/l59_292 /Users/shubi/Library/CloudStorage/OneDrive-Technion/In-lab Experiments/OneStopGaze L1 English/Full Experiment Folders/ose_1p_l1_l60_tower_st/runtime/excluded_dataviewer/l59_292
# /Users/shubi/Library/CloudStorage/OneDrive-Technion/In-lab Experiments/OneStopGaze L1 English/Full Experiment Folders/ose_2n_l1_l60_tower_st/runtime/dataviewer/l14_209 /Users/shubi/Library/CloudStorage/OneDrive-Technion/In-lab Experiments/OneStopGaze L1 English/Full Experiment Folders/ose_2n_l1_l60_tower_st/runtime/excluded_dataviewer/l14_209
# /Users/shubi/Library/CloudStorage/OneDrive-Technion/In-lab Experiments/OneStopGaze L1 English/Full Experiment Folders/ose_2n_l1_l60_tower_st/runtime/dataviewer/l19_228 /Users/shubi/Library/CloudStorage/OneDrive-Technion/In-lab Experiments/OneStopGaze L1 English/Full Experiment Folders/ose_2n_l1_l60_tower_st/runtime/excluded_dataviewer/l19_228
# /Users/shubi/Library/CloudStorage/OneDrive-Technion/In-lab Experiments/OneStopGaze L1 English/Full Experiment Folders/ose_2n_l1_l60_tower_st/runtime/dataviewer/l39_298 /Users/shubi/Library/CloudStorage/OneDrive-Technion/In-lab Experiments/OneStopGaze L1 English/Full Experiment Folders/ose_2n_l1_l60_tower_st/runtime/excluded_dataviewer/l39_298
# /Users/shubi/Library/CloudStorage/OneDrive-Technion/In-lab Experiments/OneStopGaze L1 English/Full Experiment Folders/ose_2n_l1_l60_tower_st/runtime/dataviewer/l13_208 /Users/shubi/Library/CloudStorage/OneDrive-Technion/In-lab Experiments/OneStopGaze L1 English/Full Experiment Folders/ose_2n_l1_l60_tower_st/runtime/excluded_dataviewer/l13_208
# /Users/shubi/Library/CloudStorage/OneDrive-Technion/In-lab Experiments/OneStopGaze L1 English/Full Experiment Folders/ose_2n_l1_l60_tower_st/runtime/dataviewer/l39_296 /Users/shubi/Library/CloudStorage/OneDrive-Technion/In-lab Experiments/OneStopGaze L1 English/Full Experiment Folders/ose_2n_l1_l60_tower_st/runtime/excluded_dataviewer/l39_296
# /Users/shubi/Library/CloudStorage/OneDrive-Technion/In-lab Experiments/OneStopGaze L1 English/Full Experiment Folders/ose_2n_l1_l60_tower_st/runtime/dataviewer/l37_281 /Users/shubi/Library/CloudStorage/OneDrive-Technion/In-lab Experiments/OneStopGaze L1 English/Full Experiment Folders/ose_2n_l1_l60_tower_st/runtime/excluded_dataviewer/l37_281
# /Users/shubi/Library/CloudStorage/OneDrive-Technion/In-lab Experiments/OneStopGaze L1 English/Full Experiment Folders/ose_2n_l1_l60_tower_st/runtime/dataviewer/l42_307 /Users/shubi/Library/CloudStorage/OneDrive-Technion/In-lab Experiments/OneStopGaze L1 English/Full Experiment Folders/ose_2n_l1_l60_tower_st/runtime/excluded_dataviewer/l42_307
# /Users/shubi/Library/CloudStorage/OneDrive-Technion/In-lab Experiments/OneStopGaze L1 English/Full Experiment Folders/ose_2n_l1_l60_tower_st/runtime/dataviewer/l41_301 /Users/shubi/Library/CloudStorage/OneDrive-Technion/In-lab Experiments/OneStopGaze L1 English/Full Experiment Folders/ose_2n_l1_l60_tower_st/runtime/excluded_dataviewer/l41_301
# /Users/shubi/Library/CloudStorage/OneDrive-Technion/In-lab Experiments/OneStopGaze L1 English/Full Experiment Folders/ose_2n_l1_l60_tower_st/runtime/dataviewer/l43_309 /Users/shubi/Library/CloudStorage/OneDrive-Technion/In-lab Experiments/OneStopGaze L1 English/Full Experiment Folders/ose_2n_l1_l60_tower_st/runtime/excluded_dataviewer/l43_309
# /Users/shubi/Library/CloudStorage/OneDrive-Technion/In-lab Experiments/OneStopGaze L1 English/Full Experiment Folders/ose_2n_l1_l60_tower_st/runtime/dataviewer/l48_320 /Users/shubi/Library/CloudStorage/OneDrive-Technion/In-lab Experiments/OneStopGaze L1 English/Full Experiment Folders/ose_2n_l1_l60_tower_st/runtime/excluded_dataviewer/l48_320
# /Users/shubi/Library/CloudStorage/OneDrive-Technion/In-lab Experiments/OneStopGaze L1 English/Full Experiment Folders/ose_2n_l1_l60_tower_st/runtime/dataviewer/l32_260 /Users/shubi/Library/CloudStorage/OneDrive-Technion/In-lab Experiments/OneStopGaze L1 English/Full Experiment Folders/ose_2n_l1_l60_tower_st/runtime/excluded_dataviewer/l32_260
# /Users/shubi/Library/CloudStorage/OneDrive-Technion/In-lab Experiments/OneStopGaze L1 English/Full Experiment Folders/ose_2n_l1_l60_tower_st/runtime/dataviewer/l32_261 /Users/shubi/Library/CloudStorage/OneDrive-Technion/In-lab Experiments/OneStopGaze L1 English/Full Experiment Folders/ose_2n_l1_l60_tower_st/runtime/excluded_dataviewer/l32_261
# /Users/shubi/Library/CloudStorage/OneDrive-Technion/In-lab Experiments/OneStopGaze L1 English/Full Experiment Folders/ose_2n_l1_l60_tower_st/runtime/dataviewer/l31_256 /Users/shubi/Library/CloudStorage/OneDrive-Technion/In-lab Experiments/OneStopGaze L1 English/Full Experiment Folders/ose_2n_l1_l60_tower_st/runtime/excluded_dataviewer/l31_256
# /Users/shubi/Library/CloudStorage/OneDrive-Technion/In-lab Experiments/OneStopGaze L1 English/Full Experiment Folders/ose_2n_l1_l60_tower_st/runtime/dataviewer/l45_316 /Users/shubi/Library/CloudStorage/OneDrive-Technion/In-lab Experiments/OneStopGaze L1 English/Full Experiment Folders/ose_2n_l1_l60_tower_st/runtime/excluded_dataviewer/l45_316
# /Users/shubi/Library/CloudStorage/OneDrive-Technion/In-lab Experiments/OneStopGaze L1 English/Full Experiment Folders/ose_2n_l1_l60_tower_st/runtime/dataviewer/l11_203 /Users/shubi/Library/CloudStorage/OneDrive-Technion/In-lab Experiments/OneStopGaze L1 English/Full Experiment Folders/ose_2n_l1_l60_tower_st/runtime/excluded_dataviewer/l11_203
# /Users/shubi/Library/CloudStorage/OneDrive-Technion/In-lab Experiments/OneStopGaze L1 English/Full Experiment Folders/ose_2n_l1_l60_tower_st/runtime/dataviewer/l20_231 /Users/shubi/Library/CloudStorage/OneDrive-Technion/In-lab Experiments/OneStopGaze L1 English/Full Experiment Folders/ose_2n_l1_l60_tower_st/runtime/excluded_dataviewer/l20_231
# /Users/shubi/Library/CloudStorage/OneDrive-Technion/In-lab Experiments/OneStopGaze L1 English/Full Experiment Folders/ose_2n_l1_l60_tower_st/runtime/dataviewer/l16_216 /Users/shubi/Library/CloudStorage/OneDrive-Technion/In-lab Experiments/OneStopGaze L1 English/Full Experiment Folders/ose_2n_l1_l60_tower_st/runtime/excluded_dataviewer/l16_216
# /Users/shubi/Library/CloudStorage/OneDrive-Technion/In-lab Experiments/OneStopGaze L1 English/Full Experiment Folders/ose_2n_l1_l60_tower_st/runtime/dataviewer/l32_262 /Users/shubi/Library/CloudStorage/OneDrive-Technion/In-lab Experiments/OneStopGaze L1 English/Full Experiment Folders/ose_2n_l1_l60_tower_st/runtime/excluded_dataviewer/l32_262
# /Users/shubi/Library/CloudStorage/OneDrive-Technion/In-lab Experiments/OneStopGaze L1 English/Full Experiment Folders/ose_2n_l1_l60_tower_st/runtime/dataviewer/l24_237 /Users/shubi/Library/CloudStorage/OneDrive-Technion/In-lab Experiments/OneStopGaze L1 English/Full Experiment Folders/ose_2n_l1_l60_tower_st/runtime/excluded_dataviewer/l24_237
# /Users/shubi/Library/CloudStorage/OneDrive-Technion/In-lab Experiments/OneStopGaze L1 English/Full Experiment Folders/ose_2n_l1_l60_tower_st/runtime/dataviewer/l30_252 /Users/shubi/Library/CloudStorage/OneDrive-Technion/In-lab Experiments/OneStopGaze L1 English/Full Experiment Folders/ose_2n_l1_l60_tower_st/runtime/excluded_dataviewer/l30_252
# /Users/shubi/Library/CloudStorage/OneDrive-Technion/In-lab Experiments/OneStopGaze L1 English/Full Experiment Folders/ose_1n_l1_l60_tower_st/runtime/dataviewer/l20 /Users/shubi/Library/CloudStorage/OneDrive-Technion/In-lab Experiments/OneStopGaze L1 English/Full Experiment Folders/ose_1n_l1_l60_tower_st/runtime/excluded_dataviewer/l20
# /Users/shubi/Library/CloudStorage/OneDrive-Technion/In-lab Experiments/OneStopGaze L1 English/Full Experiment Folders/ose_1n_l1_l60_tower_st/runtime/dataviewer/Test /Users/shubi/Library/CloudStorage/OneDrive-Technion/In-lab Experiments/OneStopGaze L1 English/Full Experiment Folders/ose_1n_l1_l60_tower_st/runtime/excluded_dataviewer/Test
# /Users/shubi/Library/CloudStorage/OneDrive-Technion/In-lab Experiments/OneStopGaze L1 English/Full Experiment Folders/ose_1n_l1_l60_tower_st/runtime/dataviewer/Test1 /Users/shubi/Library/CloudStorage/OneDrive-Technion/In-lab Experiments/OneStopGaze L1 English/Full Experiment Folders/ose_1n_l1_l60_tower_st/runtime/excluded_dataviewer/Test1
# /Users/shubi/Library/CloudStorage/OneDrive-Technion/In-lab Experiments/OneStopGaze L1 English/Full Experiment Folders/ose_1n_l1_l60_tower_st/runtime/dataviewer/Test2 /Users/shubi/Library/CloudStorage/OneDrive-Technion/In-lab Experiments/OneStopGaze L1 English/Full Experiment Folders/ose_1n_l1_l60_tower_st/runtime/excluded_dataviewer/Test2
# /Users/shubi/Library/CloudStorage/OneDrive-Technion/In-lab Experiments/OneStopGaze L1 English/Full Experiment Folders/ose_3n_l1_l60_tower_st_fixed/runtime/dataviewer/3n_26 /Users/shubi/Library/CloudStorage/OneDrive-Technion/In-lab Experiments/OneStopGaze L1 English/Full Experiment Folders/ose_3n_l1_l60_tower_st_fixed/runtime/excluded_dataviewer/3n_26
# /Users/shubi/Library/CloudStorage/OneDrive-Technion/In-lab Experiments/OneStopGaze L1 English/Full Experiment Folders/ose_2p_l1_l60_tower_st/runtime/dataviewer/bright /Users/shubi/Library/CloudStorage/OneDrive-Technion/In-lab Experiments/OneStopGaze L1 English/Full Experiment Folders/ose_2p_l1_l60_tower_st/runtime/excluded_dataviewer/bright
# /Users/shubi/Library/CloudStorage/OneDrive-Technion/In-lab Experiments/OneStopGaze L1 English/Full Experiment Folders/ose_2p_l1_l60_tower_st/runtime/dataviewer/test /Users/shubi/Library/CloudStorage/OneDrive-Technion/In-lab Experiments/OneStopGaze L1 English/Full Experiment Folders/ose_2p_l1_l60_tower_st/runtime/excluded_dataviewer/test
# /Users/shubi/Library/CloudStorage/OneDrive-Technion/In-lab Experiments/OneStopGaze L1 English/Full Experiment Folders/ose_2p_l1_l60_tower_st/runtime/dataviewer/testkris /Users/shubi/Library/CloudStorage/OneDrive-Technion/In-lab Experiments/OneStopGaze L1 English/Full Experiment Folders/ose_2p_l1_l60_tower_st/runtime/excluded_dataviewer/testkris
# /Users/shubi/Library/CloudStorage/OneDrive-Technion/In-lab Experiments/OneStopGaze L1 English/Full Experiment Folders/ose_2p_l1_l60_tower_st/runtime/dataviewer/Test1 /Users/shubi/Library/CloudStorage/OneDrive-Technion/In-lab Experiments/OneStopGaze L1 English/Full Experiment Folders/ose_2p_l1_l60_tower_st/runtime/excluded_dataviewer/Test1
# /Users/shubi/Library/CloudStorage/OneDrive-Technion/In-lab Experiments/OneStopGaze L1 English/Full Experiment Folders/ose_2p_l1_l60_tower_st/runtime/dataviewer/Test555 /Users/shubi/Library/CloudStorage/OneDrive-Technion/In-lab Experiments/OneStopGaze L1 English/Full Experiment Folders/ose_2p_l1_l60_tower_st/runtime/excluded_dataviewer/Test555
# /Users/shubi/Library/CloudStorage/OneDrive-Technion/In-lab Experiments/OneStopGaze L1 English/Full Experiment Folders/ose_2p_l1_l60_tower_st/runtime/dataviewer/Testc /Users/shubi/Library/CloudStorage/OneDrive-Technion/In-lab Experiments/OneStopGaze L1 English/Full Experiment Folders/ose_2p_l1_l60_tower_st/runtime/excluded_dataviewer/Testc
# /Users/shubi/Library/CloudStorage/OneDrive-Technion/In-lab Experiments/OneStopGaze L1 English/Full Experiment Folders/ose_2p_l1_l60_tower_st/runtime/dataviewer/Test2 /Users/shubi/Library/CloudStorage/OneDrive-Technion/In-lab Experiments/OneStopGaze L1 English/Full Experiment Folders/ose_2p_l1_l60_tower_st/runtime/excluded_dataviewer/Test2
# /Users/shubi/Library/CloudStorage/OneDrive-Technion/In-lab Experiments/OneStopGaze L1 English/Full Experiment Folders/ose_2p_l1_l60_tower_st/runtime/dataviewer/TestK /Users/shubi/Library/CloudStorage/OneDrive-Technion/In-lab Experiments/OneStopGaze L1 English/Full Experiment Folders/ose_2p_l1_l60_tower_st/runtime/excluded_dataviewer/TestK
# /Users/shubi/Library/CloudStorage/OneDrive-Technion/In-lab Experiments/OneStopGaze L1 English/Full Experiment Folders/ose_2p_l1_l60_tower_st/runtime/dataviewer/black /Users/shubi/Library/CloudStorage/OneDrive-Technion/In-lab Experiments/OneStopGaze L1 English/Full Experiment Folders/ose_2p_l1_l60_tower_st/runtime/excluded_dataviewer/black
# /Users/shubi/Library/CloudStorage/OneDrive-Technion/In-lab Experiments/OneStopGaze L1 English/Full Experiment Folders/ose_3p_l1_l60_tower_st_fixed/runtime/dataviewer/test /Users/shubi/Library/CloudStorage/OneDrive-Technion/In-lab Experiments/OneStopGaze L1 English/Full Experiment Folders/ose_3p_l1_l60_tower_st_fixed/runtime/excluded_dataviewer/test
# /Users/shubi/Library/CloudStorage/OneDrive-Technion/In-lab Experiments/OneStopGaze L1 English/Full Experiment Folders/ose_3p_l1_l60_tower_st_fixed/runtime/dataviewer/Testyev /Users/shubi/Library/CloudStorage/OneDrive-Technion/In-lab Experiments/OneStopGaze L1 English/Full Experiment Folders/ose_3p_l1_l60_tower_st_fixed/runtime/excluded_dataviewer/Testyev
# /Users/shubi/Library/CloudStorage/OneDrive-Technion/In-lab Experiments/OneStopGaze L1 English/Full Experiment Folders/ose_3p_l1_l60_tower_st_fixed/runtime/dataviewer/3p_26 /Users/shubi/Library/CloudStorage/OneDrive-Technion/In-lab Experiments/OneStopGaze L1 English/Full Experiment Folders/ose_3p_l1_l60_tower_st_fixed/runtime/excluded_dataviewer/3p_26
# /Users/shubi/Library/CloudStorage/OneDrive-Technion/In-lab Experiments/OneStopGaze L1 English/Full Experiment Folders/ose_3p_l1_l60_tower_st_fixed/runtime/dataviewer/testsiyi /Users/shubi/Library/CloudStorage/OneDrive-Technion/In-lab Experiments/OneStopGaze L1 English/Full Experiment Folders/ose_3p_l1_l60_tower_st_fixed/runtime/excluded_dataviewer/testsiyi
# /Users/shubi/Library/CloudStorage/OneDrive-Technion/In-lab Experiments/OneStopGaze L1 English/Full Experiment Folders/ose_3p_l1_l60_tower_st_fixed/runtime/dataviewer/l1 /Users/shubi/Library/CloudStorage/OneDrive-Technion/In-lab Experiments/OneStopGaze L1 English/Full Experiment Folders/ose_3p_l1_l60_tower_st_fixed/runtime/excluded_dataviewer/l1
# /Users/shubi/Library/CloudStorage/OneDrive-Technion/In-lab Experiments/OneStopGaze L1 English/Full Experiment Folders/ose_3p_l1_l60_tower_st_fixed/runtime/dataviewer/teste /Users/shubi/Library/CloudStorage/OneDrive-Technion/In-lab Experiments/OneStopGaze L1 English/Full Experiment Folders/ose_3p_l1_l60_tower_st_fixed/runtime/excluded_dataviewer/teste
# /Users/shubi/Library/CloudStorage/OneDrive-Technion/In-lab Experiments/OneStopGaze L1 English/Full Experiment Folders/ose_1p_l1_l60_tower_st/runtime/dataviewer/testh /Users/shubi/Library/CloudStorage/OneDrive-Technion/In-lab Experiments/OneStopGaze L1 English/Full Experiment Folders/ose_1p_l1_l60_tower_st/runtime/excluded_dataviewer/testh
# /Users/shubi/Library/CloudStorage/OneDrive-Technion/In-lab Experiments/OneStopGaze L1 English/Full Experiment Folders/ose_1p_l1_l60_tower_st/runtime/dataviewer/TestJenn /Users/shubi/Library/CloudStorage/OneDrive-Technion/In-lab Experiments/OneStopGaze L1 English/Full Experiment Folders/ose_1p_l1_l60_tower_st/runtime/excluded_dataviewer/TestJenn
# /Users/shubi/Library/CloudStorage/OneDrive-Technion/In-lab Experiments/OneStopGaze L1 English/Full Experiment Folders/ose_1p_l1_l60_tower_st/runtime/dataviewer/377l1436 /Users/shubi/Library/CloudStorage/OneDrive-Technion/In-lab Experiments/OneStopGaze L1 English/Full Experiment Folders/ose_1p_l1_l60_tower_st/runtime/excluded_dataviewer/377l1436
# /Users/shubi/Library/CloudStorage/OneDrive-Technion/In-lab Experiments/OneStopGaze L1 English/Full Experiment Folders/ose_2n_l1_l60_tower_st/runtime/dataviewer/Test2n /Users/shubi/Library/CloudStorage/OneDrive-Technion/In-lab Experiments/OneStopGaze L1 English/Full Experiment Folders/ose_2n_l1_l60_tower_st/runtime/excluded_dataviewer/Test2n
# /Users/shubi/Library/CloudStorage/OneDrive-Technion/In-lab Experiments/OneStopGaze L1 English/Full Experiment Folders/ose_2n_l1_l60_tower_st/runtime/dataviewer/Test1n /Users/shubi/Library/CloudStorage/OneDrive-Technion/In-lab Experiments/OneStopGaze L1 English/Full Experiment Folders/ose_2n_l1_l60_tower_st/runtime/excluded_dataviewer/Test1n
# /Users/shubi/Library/CloudStorage/OneDrive-Technion/In-lab Experiments/OneStopGaze L1 English/Full Experiment Folders/ose_2n_l1_l60_tower_st/runtime/dataviewer/restart /Users/shubi/Library/CloudStorage/OneDrive-Technion/In-lab Experiments/OneStopGaze L1 English/Full Experiment Folders/ose_2n_l1_l60_tower_st/runtime/excluded_dataviewer/restart
# /Users/shubi/Library/CloudStorage/OneDrive-Technion/In-lab Experiments/OneStopGaze L1 English/Full Experiment Folders/ose_2n_l1_l60_tower_st/runtime/dataviewer/jonthes2 /Users/shubi/Library/CloudStorage/OneDrive-Technion/In-lab Experiments/OneStopGaze L1 English/Full Experiment Folders/ose_2n_l1_l60_tower_st/runtime/excluded_dataviewer/jonthes2
# /Users/shubi/Library/CloudStorage/OneDrive-Technion/In-lab Experiments/OneStopGaze L1 English/Full Experiment Folders/ose_2n_l1_l60_tower_st/runtime/dataviewer/testk /Users/shubi/Library/CloudStorage/OneDrive-Technion/In-lab Experiments/OneStopGaze L1 English/Full Experiment Folders/ose_2n_l1_l60_tower_st/runtime/excluded_dataviewer/testk
# /Users/shubi/Library/CloudStorage/OneDrive-Technion/In-lab Experiments/OneStopGaze L1 English/Full Experiment Folders/ose_2n_l1_l60_tower_st/runtime/dataviewer/jonthesi /Users/shubi/Library/CloudStorage/OneDrive-Technion/In-lab Experiments/OneStopGaze L1 English/Full Experiment Folders/ose_2n_l1_l60_tower_st/runtime/excluded_dataviewer/jonthesi
# /Users/shubi/Library/CloudStorage/OneDrive-Technion/In-lab Experiments/OneStopGaze L1 English/Full Experiment Folders/ose_2n_l1_l60_tower_st/runtime/dataviewer/Test3n /Users/shubi/Library/CloudStorage/OneDrive-Technion/In-lab Experiments/OneStopGaze L1 English/Full Experiment Folders/ose_2n_l1_l60_tower_st/runtime/excluded_dataviewer/Test3n
